# %% [markdown]
# # Licitações realizadas pela Universidade Federal do Paraná (2014~2020)
# # Relatório de Análise de Dados I

# %% [markdown]
# ## Importando Dados

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
dados = pd.read_csv('dadosTratados.csv', sep = ';')

# %%
homologados = dados.query("situacao == 'Homologado'")
homologados.head()
# Out:
#      ano            modalidade numero_ano        processo    situacao  \
# 5   2014  Concorrência Pública   005/2014  001426/2014-16  Homologado
# 7   2014  Concorrência Pública   007/2014  047629/2013-78  Homologado
# 8   2014  Concorrência Pública   008/2014  013682/2014-56  Homologado
# 9   2014  Concorrência Pública   009/2014  007760/2014-83  Homologado
# 12  2014     Pregão Eletrônico   018/2014  01.392/2014-60  Homologado
#
#                                                objeto        natureza  \
# 5   Concessão de uso de espaço físico para explora...  Sem Informação
# 7   Concessão de uso de espaço físico, cantina do ...  Sem Informação
# 8              Permissão de uso reprografia jurídicas  Sem Informação
# 9   Concessão de uso de espaço físico para funcion...  Sem Informação
# 12  Aquisição de materiais hidráulicos para manute...        material
#
#      demandante modalidade_compra  homologacao_mes  valor_estimado_ufpr  \
# ...

# %%
hom_ano = homologados.ano.value_counts().to_frame().sort_index()
hom_ano.rename(columns = {'ano' : 'Processos'}, inplace=True)
hom_ano.index.name = 'Ano'
hom_ano
# Out:
#       Processos
# Ano
# 2014        169
# 2015        131
# 2016        167
# 2017        124
# 2018        185
# 2019        151
# 2020        112

# %%
sns.set_palette('Accent')
sns.set_style('darkgrid')
ax = sns.lineplot(x='Ano', y='Processos', data=hom_ano)
ax.figure.set_size_inches(12, 6)
ax.set_title('Processos homologados por ano', loc='left', fontsize=18)
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Processos Homologados', fontsize=14)
ax = ax

# %%
fig2 = sns.displot(data=homologados, x='modalidade', weights=3, aspect=2.67)
fig2.fig.suptitle('Processos homologados por modalidade (2014 - 2020)', 
                  fontsize=16,
                  y=1.05,
                  x=0.17
                 )
ax = fig2
